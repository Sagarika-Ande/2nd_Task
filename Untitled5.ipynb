# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagarika-Ande/2nd_Task/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trip_data=pd.read_csv('/content/client1_trip_data.csv')
print(trip_data)
# Out:
#      Unnamed: 0 deviceHostTag   TripId                 adminid  \
# 0             0     GJ38T4876  A082432  38jiotowerfo@gmail.com
# 1             2     KA20D1836  A082745  38jiotowerfo@gmail.com
# 2             3    UP81CT4813  A082903  38jiotowerfo@gmail.com
# 3             4    CG10AZ2390  A084199  38jiotowerfo@gmail.com
# 4             8    TN01BL8860  A086167  38jiotowerfo@gmail.com
# ..          ...           ...      ...                     ...
# 461         993    CG07CH1579  A093430  38jiotowerfo@gmail.com
# 462         994     KA29B9934  A093870  38jiotowerfo@gmail.com
# 463         996    DL1LAB6077  A095059  38jiotowerfo@gmail.com
# 464         997     UP20T4078  A095643  38jiotowerfo@gmail.com
# 465         998      WB057330  A097275  38jiotowerfo@gmail.com
#
#              trip_eta_status trackingstatus tripselecttype  initialETA  \
# 0                     Ontime        Tracked            GPS  1735832846
# ...

# %%
print(trip_data.head())
print(trip_data.tail())
print(trip_data.shape)
# Out:
#    Unnamed: 0 deviceHostTag   TripId                 adminid  \
# 0           0     GJ38T4876  A082432  38jiotowerfo@gmail.com
# 1           2     KA20D1836  A082745  38jiotowerfo@gmail.com
# 2           3    UP81CT4813  A082903  38jiotowerfo@gmail.com
# 3           4    CG10AZ2390  A084199  38jiotowerfo@gmail.com
# 4           8    TN01BL8860  A086167  38jiotowerfo@gmail.com
#
#            trip_eta_status trackingstatus tripselecttype  initialETA  \
# 0                   Ontime        Tracked            GPS  1735832846
# 1  Delay - 19 hrs 25 mins         Tracked            GPS  1735825406
# 2   Delay - 10 hrs 9 mins         Tracked            GPS  1735854482
# 3  Delay - 20 hrs 47 mins         Tracked            GPS  1736063868
# 4           Delay - 1 min         Tracked            GPS  1736399762
#
#    summary_tripStartTimestamp  summary_tripEndTimestamp  ...  \
# 0               1735794476000             1735808435000  ...
# ...

# %%
print(trip_data.describe())
print(trip_data.info())
# Out:
#        Unnamed: 0    initialETA  summary_tripStartTimestamp  \
# count  466.000000  4.660000e+02                4.660000e+02
# mean   508.759657  1.739227e+09                1.739224e+12
# std    282.279420  2.353363e+06                2.353478e+09
# min      0.000000  1.735628e+09                1.735621e+12
# 25%    261.000000  1.736925e+09                1.736921e+12
# 50%    520.500000  1.739057e+09                1.739053e+12
# 75%    744.500000  1.741177e+09                1.741173e+12
# max    998.000000  1.743440e+09                1.743436e+12
#
#        summary_tripEndTimestamp  summary_totalGPSDistanceKms  \
# count              4.660000e+02                   466.000000
# mean               1.739263e+12                    21.962914
# std                2.353061e+09                    32.026540
# min                1.735709e+12                     0.000003
# 25%                1.736961e+12                     1.250154
# ...

# %%
print(trip_data.isnull().sum())
# Out:
# Unnamed: 0                      0
# deviceHostTag                   0
# TripId                          0
# adminid                         0
# trip_eta_status                 0
# trackingstatus                  0
# tripselecttype                  0
# initialETA                      0
# summary_tripStartTimestamp      0
# summary_tripEndTimestamp        0
# TripStartDateTime               0
# TripEndDateTime                 0
# summary_totalGPSDistanceKms     0
# modeOfClosureValue              0
# DriverName                      0
# DriverMobileNumber              0
# pdid                            0
# AssetType                       0
# source_addr                     0
# destination_addr                0
# ContractorName_Owned            0
# ContractorMobileNumber          0
# actualtransittime_Value         0
# actualtransittime_Units         0
# DistanceCategory                0
# isMarketVehicle                 0
# TripStatus                      0
# ...

# %%
data=trip_data.dropna()
print(data)
# Out:
#      Unnamed: 0 deviceHostTag   TripId                 adminid  \
# 0             0     GJ38T4876  A082432  38jiotowerfo@gmail.com
# 1             2     KA20D1836  A082745  38jiotowerfo@gmail.com
# 2             3    UP81CT4813  A082903  38jiotowerfo@gmail.com
# 3             4    CG10AZ2390  A084199  38jiotowerfo@gmail.com
# 4             8    TN01BL8860  A086167  38jiotowerfo@gmail.com
# ..          ...           ...      ...                     ...
# 461         993    CG07CH1579  A093430  38jiotowerfo@gmail.com
# 462         994     KA29B9934  A093870  38jiotowerfo@gmail.com
# 463         996    DL1LAB6077  A095059  38jiotowerfo@gmail.com
# 464         997     UP20T4078  A095643  38jiotowerfo@gmail.com
# 465         998      WB057330  A097275  38jiotowerfo@gmail.com
#
#              trip_eta_status trackingstatus tripselecttype  initialETA  \
# 0                     Ontime        Tracked            GPS  1735832846
# ...
